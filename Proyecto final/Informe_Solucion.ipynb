# %% [markdown]
# Hola **Fernando**!
#
# Soy **Patricio Requena** 👋. Es un placer ser el revisor de tu proyecto el día de hoy!
#
# Revisaré tu proyecto detenidamente con el objetivo de ayudarte a mejorar y perfeccionar tus habilidades. Durante mi revisión, identificaré áreas donde puedas hacer mejoras en tu código, señalando específicamente qué y cómo podrías ajustar para optimizar el rendimiento y la claridad de tu proyecto. Además, es importante para mí destacar los aspectos que has manejado excepcionalmente bien. Reconocer tus fortalezas te ayudará a entender qué técnicas y métodos están funcionando a tu favor y cómo puedes aplicarlos en futuras tareas.
#
# _**Recuerda que al final de este notebook encontrarás un comentario general de mi parte**_, empecemos!
#
# Encontrarás mis comentarios dentro de cajas verdes, amarillas o rojas, ⚠️ **por favor, no muevas, modifiques o borres mis comentarios** ⚠️:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>

# %% [markdown]
# # Informe de solución – Proyecto final
#
# ## ¿Qué pasos del plan se realizaron y cuáles se omitieron?
#
# Durante el desarrollo de este proyecto se realizaron los pasos principales del plan, comenzando con la carga y revisión de los datos.
# Posteriormente, se unificaron las tablas utilizando el identificador del cliente y se llevó a cabo el preprocesamiento, donde se trataron valores faltantes y se transformaron variables categóricas.
#
# El análisis exploratorio permitió entender la distribución de la variable objetivo y preparar los datos para el entrenamiento de modelos.
# Finalmente, se entrenaron y evaluaron distintos modelos de clasificación.
#
# El archivo relacionado con los servicios de internet no pudo integrarse al conjunto de datos, ya que no contenía la columna `customerID`. Por esta razón, este paso fue omitido y el análisis se realizó con la información disponible.
#
# ---
#
# ## ¿Qué dificultades se encontraron y cómo se resolvieron?
#
# La principal dificultad encontrada fue un error al intentar unir los datos, debido a que uno de los archivos no tenía el identificador necesario.
# Este problema se resolvió revisando los nombres de las columnas y ajustando el proceso de unificación de los datos.
#
# También se encontraron valores faltantes después de la unión de las tablas, los cuales fueron tratados durante el preprocesamiento para evitar problemas en el entrenamiento de los modelos.
#
# ---
#
# ## ¿Cuáles fueron los pasos clave para resolver la tarea?
#
# Uno de los pasos clave fue la correcta preparación de los datos, ya que esto permitió que los modelos funcionaran correctamente.
# Otro paso importante fue la definición de la variable objetivo de cancelación y la comparación del desempeño de los distintos modelos entrenados.
#
# ---
#
# ## ¿Cuál es el modelo final y qué nivel de calidad tiene?
#
# Se entrenaron diferentes modelos de clasificación y se compararon sus resultados utilizando métricas de calidad.
# El modelo que presentó el mejor desempeño fue **Random Forest**, ya que obtuvo el valor más alto de ROC-AUC en el conjunto de prueba.
#
# Este modelo puede utilizarse para identificar clientes con mayor probabilidad de cancelar el servicio y apoyar la toma de decisiones del área de marketing.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario general (1ra Iteracion)</b> <a class=“tocSkip”></a>
#
# ¡Felicidades Fernando! Completaste tu proyecto con un informe bastante detallado de los resultados obtenidos y los pasos realizados para llegar hasta ellos.
#
# La redacción de tus pasos y procesos es muy clara, redactaste muy bien los resultados de tu modelo y las métricas utilizadas dejando claro que el entrenamiento y evaluación salieron de manera correcta.
#
# Sin más, sólo me queda decir que la práctica hace al maestro, te invito a seguir profundizando en más tecnicas de machine learning y también a como llevar estos modelos a un entorno productivo donde pueda dar más valor a la empresa para la cual se lo plantee. Recuerda que los proyectos de datos siempre deben ir de la mano con los objetivos de la empresa, siempre deben buscar el beneficio de la misma por lo que es clave que primero se entienda el funcionamiento del negocio antes de pasar a cualquier proyecto.
#
# Saludos!
# </div>
